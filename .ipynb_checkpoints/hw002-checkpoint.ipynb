# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
f=plt.figure()#建圖形
ax=plt.axes()#建坐標軸
x=np.linspace(123,456,10000)#令函數
y=np.linspace(38,87,10000)
plt.plot(x,np.cos(y),color='#548C00',linestyle='--')#畫圖，顏色，虛線
