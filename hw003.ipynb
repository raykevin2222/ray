# %% [markdown]
# #### 色彩轉換

# %%
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread('dog.jpg')
print(image,type(image))
plt.imshow(image)
plt.show()
# Out:
# [[[ 14  42  77]
#   [ 18  46  81]
#   [ 24  51  88]
#   ...
#   [ 45 101 172]
#   [ 46 102 173]
#   [ 41 100 170]]
#
#  [[ 11  39  74]
#   [ 15  43  78]
#   [ 21  48  85]
#   ...
#   [ 45 101 172]
#   [ 46 102 173]
#   [ 42 101 171]]
#
#  [[  7  33  69]
#   [ 10  36  72]
#   [ 16  42  79]
#   ...
#   [ 45 101 172]
#   [ 46 102 173]
#   [ 42 101 170]]
#
#  ...
#
#  [[214 223 226]
#   [238 247 250]
#   [233 242 245]
#   ...
#   [ 46  85 140]
#   [ 47  84 140]
#   [ 42  78 132]]
#
#  [[214 223 226]
#   [239 248 251]
#   [234 243 246]
#   ...
#   [ 46  85 140]
#   [ 47  84 140]
#   [ 53  89 143]]
#
#  [[215 224 227]
#   [240 249 252]
#   [235 244 247]
#   ...
#   [ 46  85 140]
#   [ 47  84 140]
#   [ 41  77 131]]] <class 'numpy.ndarray'>

# %%
image = cv2.imread('dog.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)
plt.show()
